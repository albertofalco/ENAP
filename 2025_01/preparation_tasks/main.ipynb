# %%
# Escuela de Negocios y Administración Pública
# Facultad de Ciencias Económicas - Universidad de Buenos Aires
# Esp. Cr. Alberto Falco

# %%
# Instalación de librerías.
! pip install Faker
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 29.0 MB/s eta 0:00:00
# ...

# %%
# Importacion de librerias.
import pandas as pd
import numpy as np
from faker import Faker

# %%
# Lectura del archivo csv.
df = pd.read_csv("./Comprehensive_Banking_Database.csv")
df.head()
# Out:
#    Customer ID First Name Last Name  Age  Gender    Address           City  \
# 0            1     Joshua      Hall   45    Male  Address_1     Fort Worth
# 1            2       Mark    Taylor   47  Female  Address_2     Louisville
# 2            3     Joseph    Flores   25  Female  Address_3   Philadelphia
# 3            4      Kevin       Lee   52   Other  Address_4  Oklahoma City
# 4            5      Linda   Johnson   68   Other  Address_5        Phoenix
#
#    Contact Number                  Email Account Type  ...  \
# 0     19458794854    joshua.hall@kag.com      Current  ...
# 1     19458794855    mark.taylor@kag.com      Current  ...
# 2     19458794856  joseph.flores@kag.com      Current  ...
# 3     19458794857      kevin.lee@kag.com      Savings  ...
# 4     19458794858  linda.johnson@kag.com      Savings  ...
#
#    Minimum Payment Due Payment Due Date Last Credit Card Payment Date  \
# 0               226.22       11/26/2023                     3/20/2023
# ...

# %%
# Impresión de atributos.
print(df.columns)
# Out:
# Index(['Customer ID', 'First Name', 'Last Name', 'Age', 'Gender', 'Address',
#        'City', 'Contact Number', 'Email', 'Account Type', 'Account Balance',
#        'Date Of Account Opening', 'Last Transaction Date', 'TransactionID',
#        'Transaction Date', 'Transaction Type', 'Transaction Amount',
#        'Account Balance After Transaction', 'Branch ID', 'Loan ID',
#        'Loan Amount', 'Loan Type', 'Interest Rate', 'Loan Term',
#        'Approval/Rejection Date', 'Loan Status', 'CardID', 'Card Type',
#        'Credit Limit', 'Credit Card Balance', 'Minimum Payment Due',
#        'Payment Due Date', 'Last Credit Card Payment Date', 'Rewards Points',
#        'Feedback ID', 'Feedback Date', 'Feedback Type', 'Resolution Status',
#        'Resolution Date', 'Anomaly'],
#       dtype='object')

# %%
# Reducción de atributos.
columns_to_drop = ['Branch ID', 'Loan ID',
       'Loan Amount', 'Loan Type', 'Interest Rate', 'Loan Term',
       'Approval/Rejection Date', 'Loan Status', 'CardID', 'Card Type',
       'Credit Limit', 'Credit Card Balance', 'Minimum Payment Due',
       'Payment Due Date', 'Last Credit Card Payment Date', 'Rewards Points',
       'Feedback ID', 'Feedback Date', 'Feedback Type', 'Resolution Status',
       'Resolution Date', 'Anomaly']
df = df.drop(columns=columns_to_drop)

# %%
# Impresión de primeros registros.
df.head()
# Out:
#    Customer ID First Name Last Name  Age  Gender    Address           City  \
# 0            1     Joshua      Hall   45    Male  Address_1     Fort Worth
# 1            2       Mark    Taylor   47  Female  Address_2     Louisville
# 2            3     Joseph    Flores   25  Female  Address_3   Philadelphia
# 3            4      Kevin       Lee   52   Other  Address_4  Oklahoma City
# 4            5      Linda   Johnson   68   Other  Address_5        Phoenix
#
#    Contact Number                  Email Account Type  Account Balance  \
# 0     19458794854    joshua.hall@kag.com      Current          1313.38
# 1     19458794855    mark.taylor@kag.com      Current          5988.46
# 2     19458794856  joseph.flores@kag.com      Current          8277.88
# 3     19458794857      kevin.lee@kag.com      Savings          7487.21
# 4     19458794858  linda.johnson@kag.com      Savings          6993.55
#
#   Date Of Account Opening Last Transaction Date  TransactionID  \
# ...

# %%
# Shape del dataframe resultante.
df.shape
# Out:
# (5000, 18)

# %%
# Obtención aleatoria de 500 registros.
# Se utiliza la librería numpy.

# Fijación de la semilla.
np.random.seed(42)

# Se obtiene la muestra aleatoria de los 500 registros.
df_sample = df.sample(n=500)

# Head del df_sample.
df_sample.head()
# Out:
#       Customer ID First Name Last Name  Age  Gender       Address  \
# 1501         1502      Kevin   Jackson   50  Female  Address_1502
# 2586         2587   Jennifer   Johnson   29   Other  Address_2587
# 2653         2654      Emily  Williams   69  Female  Address_2654
# 1055         1056   Margaret    Taylor   59  Female  Address_1056
# 705           706      Brian     Allen   20  Female   Address_706
#
#              City  Contact Number                     Email Account Type  \
# 1501  Kansas City     19458796355     kevin.jackson@kag.com      Current
# 2586    Las Vegas     19458797440  jennifer.johnson@kag.com      Current
# 2653      El Paso     19458797507    emily.williams@kag.com      Current
# 1055     New York     19458795909   margaret.taylor@kag.com      Savings
# 705        Boston     19458795559       brian.allen@kag.com      Savings
#
#       Account Balance Date Of Account Opening Last Transaction Date  \
# ...

# %%
# Instaciación del objeto faker.
fake = Faker()

# %%
# Función para generar valores vacíos.
def na_generator(x):
  if fake.boolean(chance_of_getting_true=50):
    return x
  else:
    return ""

# Aplicación de la función a todas las celdas.
Faker.seed(42)
df_sample.map(func=na_generator)
# Out:
#      Customer ID First Name Last Name Age  Gender       Address          City  \
# 1501                          Jackson              Address_1502   Kansas City
# 2586        2587              Johnson  29          Address_2587     Las Vegas
# 2653        2654      Emily  Williams      Female  Address_2654
# 1055               Margaret            59  Female  Address_1056      New York
# 705          706      Brian            20  Female                      Boston
# ...          ...        ...       ...  ..     ...           ...           ...
# 3928        3929     Ashley    Taylor  60    Male  Address_3929  Indianapolis
# 544          545     Amanda
# 367                  Ronald                  Male                  Fort Worth
# 1612                  Emily                 Other
# 3550                  Brian    Rivera                                 Phoenix
#
#      Contact Number                     Email Account Type Account Balance  \
# ...

# %%
# Función para asignar valores fake.
def fake_applier(x, scope=50):
  if fake.boolean(chance_of_getting_true=scope):
    return fake.street_address()
  else:
    return x

# Aplicación de la función a todas las celdas.
Faker.seed(42)
df_sample["Address"].apply(func=fake_applier)
# Out:
# 1501                       Address_1502
# 2586                   433 Jill Springs
# 2653                       Address_2654
# 1055                       Address_1056
# 705      01338 Anna Stravenue Suite 379
#                      ...
# 3928                       Address_3929
# 544                         Address_545
# 367     74517 Kimberly Freeway Apt. 959
# 1612                       Address_1613
# 3550                       Address_3551
# Name: Address, Length: 500, dtype: object

# %%
# Función para asignar valores fake.
def fake_applier(x, scope=50):
  if fake.boolean(chance_of_getting_true=scope):
    return fake.email()
  else:
    return x

# Aplicación de la función a todas las celdas.
Faker.seed(42)
df_sample["Email"].apply(func=fake_applier)
# Out:
# 1501         kevin.jackson@kag.com
# 2586      figueroajohn@example.org
# 2653        emily.williams@kag.com
# 1055      garzaanthony@example.org
# 705     williamjohnson@example.org
#                    ...
# 3928         ashley.taylor@kag.com
# 544             mark07@example.net
# 367           ronald.smith@kag.com
# 1612       omarpadilla@example.net
# 3550          brian.rivera@kag.com
# Name: Email, Length: 500, dtype: object

# %%
# Función para asignar valores fake.
def fake_applier(x, scope=50):
  if fake.boolean(chance_of_getting_true=scope):
    return fake.first_name()
  else:
    return x

# Aplicación de la función a todas las celdas.
Faker.seed(42)
df_sample["First Name"].apply(func=fake_applier)
# Out:
# 1501     Kevin
# 2586     Angel
# 2653      John
# 1055      Jill
# 705      Brian
#          ...
# 3928    Ashley
# 544     Amanda
# 367     Marcus
# 1612    Mariah
# 3550    Joshua
# Name: First Name, Length: 500, dtype: object

# %%
# Función para asignar valores fake.
def fake_applier(x, scope=50):
  if fake.boolean(chance_of_getting_true=scope):
    return fake.last_name()
  else:
    return x

# Aplicación de la función a todas las celdas.
Faker.seed(42)
df_sample["Last Name"].apply(func=fake_applier)
# Out:
# 1501    Jackson
# 2586    Johnson
# 2653    Sanchez
# 1055      Doyle
# 705       Allen
#          ...
# 3928     Taylor
# 544     Sanchez
# 367      Morris
# 1612      Rivas
# 3550    Ramirez
# Name: Last Name, Length: 500, dtype: object

# %%
# Función para asignar valores fake.
def fake_applier(x, scope=50):
  if fake.boolean(chance_of_getting_true=scope):
    return fake.city()
  else:
    return x

# Aplicación de la función a todas las celdas.
Faker.seed(42)
df_sample["City"].apply(func=fake_applier)
# Out:
# 1501                Kansas City
# 2586            Lake Joshuabury
# 2653               Lake Joyside
# 1055                Johnsonland
# 705                 New Carolyn
#                  ...
# 3928                  Rossville
# 544                 Edwardsview
# 367                 Lake Sandra
# 1612    Port Christopherchester
# 3550                   Lisaside
# Name: City, Length: 500, dtype: object

# %%
# Función para asignar valores fake.
def fake_applier(x, scope=50):
  if fake.boolean(chance_of_getting_true=scope):
    return fake.date(pattern="%m/%d/%Y")
  else:
    return x

# Aplicación de la función a todas las celdas.
Faker.seed(42)
df_sample["Transaction Date"].apply(func=fake_applier)
# Out:
# 1501    10/18/2023
# 2586    05/21/1971
# 2653    07/23/1983
# 1055    10/08/2010
# 705      3/26/2023
#            ...
# 3928     5/28/2023
# 544      1/10/2023
# 367     11/04/1987
# 1612    12/27/2015
# 3550    06/10/1985
# Name: Transaction Date, Length: 500, dtype: object

# %%
# Función para asignar valores fake.
def fake_applier(x, scope=50):
  if fake.boolean(chance_of_getting_true=scope):
    return fake.random_int(min=10, max=100)
  else:
    return x

# Aplicación de la función a todas las celdas.
Faker.seed(42)
df_sample["Age"].apply(func=fake_applier)
# Out:
# 1501    50
# 2586    13
# 2653    69
# 1055    41
# 705     27
#         ..
# 3928    60
# 544     25
# 367     20
# 1612    44
# 3550    66
# Name: Age, Length: 500, dtype: int64

# %%
# Obtención de media y desvio estandar.
mean = np.mean(df_sample["Transaction Amount"])
std_dev = np.std(df_sample["Transaction Amount"])

# Función para asignar valores fake.
def fake_applier(x, scope=50):
  if fake.boolean(chance_of_getting_true=scope):
    return np.random.normal(loc=mean, scale=std_dev)
  else:
    return x

# Aplicación de la función a todas las celdas.
Faker.seed(42)
np.random.seed(42)
df_sample["Transaction Amount"].apply(func=fake_applier)
# Out:
# 1501     144.470000
# 2586    3060.508259
# 2653    2147.270685
# 1055    2202.170000
# 705     3277.642369
#            ...
# 3928    1328.341809
# 544     2984.434103
# 367     1900.080000
# 1612    2258.410000
# 3550    2703.020000
# Name: Transaction Amount, Length: 500, dtype: float64
